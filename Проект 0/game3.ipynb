# %%
from game3 import score_game
from game3 import super_predict
score_game(super_predict)
# Out:
# ваш алгоритм нашел загаданное число за: 3 попыток. Это число 38
# ваш алгоритм нашел загаданное число за: 3 попыток. Это число 13
# ваш алгоритм нашел загаданное число за: 7 попыток. Это число 73
# ваш алгоритм нашел загаданное число за: 5 попыток. Это число 10
# ваш алгоритм нашел загаданное число за: 2 попыток. Это число 76
# ваш алгоритм нашел загаданное число за: 7 попыток. Это число 6
# ваш алгоритм нашел загаданное число за: 6 попыток. Это число 80
# ваш алгоритм нашел загаданное число за: 7 попыток. Это число 65
# ваш алгоритм нашел загаданное число за: 6 попыток. Это число 17
# ваш алгоритм нашел загаданное число за: 6 попыток. Это число 2
# ваш алгоритм нашел загаданное число за: 6 попыток. Это число 77
# ваш алгоритм нашел загаданное число за: 5 попыток. Это число 72
# ваш алгоритм нашел загаданное число за: 4 попыток. Это число 7
# ваш алгоритм нашел загаданное число за: 2 попыток. Это число 26
# ваш алгоритм нашел загаданное число за: 1 попыток. Это число 51
# ...
